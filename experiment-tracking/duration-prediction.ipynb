# %%
# !python -V
# Out:
# Python 3.9.16

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
# Add mlflow
import mlflow

mlflow.set_tracking_uri('sqlite:///mlflow.db')
mlflow.set_experiment('nyc-taxi-experiment')
# Out:
# <Experiment: artifact_location='/Users/addingtongraham/github-repos/mlops/experiment-tracking/mlruns/1', creation_time=1683754500621, experiment_id='1', last_update_time=1683754500621, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
df = pd.read_parquet('./data/green_tripdata_2021-01.parquet')

df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

df = df[(df.duration >= 1) & (df.duration <= 60)]

categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 9.838799799829626

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.legend()
# Out:
# /var/folders/04/whwls5095tz8s5mxv15jpsvr0000gn/T/ipykernel_73507/1672306066.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='prediction')
# /var/folders/04/whwls5095tz8s5mxv15jpsvr0000gn/T/ipykernel_73507/1672306066.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train, label='actual')

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.758715206931833

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
lr = Lasso(0.01)
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 11.167275941179728

# %% [markdown]
# ## DEFINE MLFLOW RUN

# %%
with mlflow.start_run():
    
    mlflow.set_tag('developer', 'kai')
    mlflow.log_param('train-data-path', './data/green_tripdata_2021-01.parquet')
    mlflow.log_param('valid-data-path', './data/green_tripdata_2021-02.parquet')
    
    alpha = 0.012
    mlflow.log_param('alpha', alpha)
    
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)

    mse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric('mse', mse)

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
# define train and validation
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    
    with mlflow.start_run():
        mlflow.set_tag('model', 'xgboost')
        mlflow.log_params(params)
        booster = xgb.train(
            params = params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid,'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric('rmse', rmse)
    
    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42,    
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [11:59:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17.54741
# [1]	validation-rmse:14.73920
# [2]	validation-rmse:12.60128
# [3]	validation-rmse:10.99616
# [4]	validation-rmse:9.80589
# [5]	validation-rmse:8.93577
# [6]	validation-rmse:8.30833
# [7]	validation-rmse:7.86108
# [8]	validation-rmse:7.54025
# [9]	validation-rmse:7.30966
# [10]	validation-rmse:7.14714
# [11]	validation-rmse:7.02713
# [12]	validation-rmse:6.93861
# [13]	validation-rmse:6.87466
# [14]	validation-rmse:6.82521
# [15]	validation-rmse:6.78784
# [16]	validation-rmse:6.75934
# [17]	validation-rmse:6.73738
# [18]	validation-rmse:6.72077
# [19]	validation-rmse:6.70810
# [20]	validation-rmse:6.69504
# [21]	validation-rmse:6.68560
# [22]	validation-rmse:6.67864
# [23]	validation-rmse:6.67165
# [24]	validation-rmse:6.66646
# [25]	validation-rmse:6.66232
# [26]	validation-rmse:6.65911
# [27]	validation-rmse:6.65622
# [28]	validation-rmse:6.65399
# [29]	validation-rmse:6.65164
# [30]	validation-rmse:6.65058
# [31]	validation-rmse:6.64921
# [32]	validation-rmse:6.64773
# [33]	validation-rmse:6.64627
# [34]	validation-rmse:6.64558
# [35]	validation-rmse:6.64451
# [36]	validation-rmse:6.64366
# [37]	validation-rmse:6.64245
# [38]	validation-rmse:6.64184
# [39]	validation-rmse:6.64133
# [40]	validation-rmse:6.64042
# [41]	validation-rmse:6.64047
# [42]	validation-rmse:6.64006
# [43]	validation-rmse:6.63962
# [44]	validation-rmse:6.63938
# [45]	validation-rmse:6.63899
# [46]	validation-rmse:6.63859
# [47]	validation-rmse:6.63811
# [48]	validation-rmse:6.63787
# [49]	validation-rmse:6.63741
# [50]	validation-rmse:6.63707
# [51]	validation-rmse:6.63706
# [52]	validation-rmse:6.63660
# [53]	validation-rmse:6.63594
# [54]	validation-rmse:6.63551
# [55]	validation-rmse:6.63518
# [56]	validation-rmse:6.63505
# [57]	validation-rmse:6.63446
# [58]	validation-rmse:6.63469
# [59]	validation-rmse:6.63445
# [60]	validation-rmse:6.63431
# [61]	validation-rmse:6.63421
# [62]	validation-rmse:6.63420
# [63]	validation-rmse:6.63376
# [64]	validation-rmse:6.63369
# [65]	validation-rmse:6.63347
# [66]	validation-rmse:6.63320
# [67]	validation-rmse:6.63307
# [68]	validation-rmse:6.63275
# [69]	validation-rmse:6.63246
# [70]	validation-rmse:6.63240
# [71]	validation-rmse:6.63223
# [72]	validation-rmse:6.63212
# [73]	validation-rmse:6.63200
# [74]	validation-rmse:6.63163
# [75]	validation-rmse:6.63130
# [76]	validation-rmse:6.63160
# [77]	validation-rmse:6.63107
# [78]	validation-rmse:6.63107
# [79]	validation-rmse:6.63106
# [80]	validation-rmse:6.63102
# [81]	validation-rmse:6.63097
# [82]	validation-rmse:6.63124
# [83]	validation-rmse:6.63123
# [84]	validation-rmse:6.63117
# [85]	validation-rmse:6.63086
# [86]	validation-rmse:6.63073
# [87]	validation-rmse:6.63033
# [88]	validation-rmse:6.63024
# [89]	validation-rmse:6.63050
# [90]	validation-rmse:6.63021
# [91]	validation-rmse:6.62967
# [92]	validation-rmse:6.62971
# [93]	validation-rmse:6.62897
# [94]	validation-rmse:6.62884
# [95]	validation-rmse:6.62836
# [96]	validation-rmse:6.62837
# [97]	validation-rmse:6.62843
# [98]	validation-rmse:6.62821
# [99]	validation-rmse:6.62806
# [100]	validation-rmse:6.62815
# [101]	validation-rmse:6.62770
# [102]	validation-rmse:6.62753
# [103]	validation-rmse:6.62773
# [104]	validation-rmse:6.62760
# [105]	validation-rmse:6.62748
# [106]	validation-rmse:6.62740
# [107]	validation-rmse:6.62720
# [108]	validation-rmse:6.62771
# [109]	validation-rmse:6.62779
# [110]	validation-rmse:6.62773
# [111]	validation-rmse:6.62751
# [112]	validation-rmse:6.62791
# [113]	validation-rmse:6.62808
# [114]	validation-rmse:6.62784
# [115]	validation-rmse:6.62771
# [116]	validation-rmse:6.62743
# [117]	validation-rmse:6.62760
# [118]	validation-rmse:6.62737
# [119]	validation-rmse:6.62730
# [120]	validation-rmse:6.62749
# [121]	validation-rmse:6.62742
# [122]	validation-rmse:6.62744
# [123]	validation-rmse:6.62755
# [124]	validation-rmse:6.62774
# [125]	validation-rmse:6.62766
# [126]	validation-rmse:6.62776
# [127]	validation-rmse:6.62790
# [128]	validation-rmse:6.62774
# [129]	validation-rmse:6.62753
# [130]	validation-rmse:6.62738
# [131]	validation-rmse:6.62729
# [132]	validation-rmse:6.62732
# [133]	validation-rmse:6.62744
# [134]	validation-rmse:6.62754
# [135]	validation-rmse:6.62757
# [136]	validation-rmse:6.62740
# [137]	validation-rmse:6.62722
# [138]	validation-rmse:6.62716
# [139]	validation-rmse:6.62689
# [140]	validation-rmse:6.62685
# [141]	validation-rmse:6.62670
# [142]	validation-rmse:6.62692
# [143]	validation-rmse:6.62701
# [144]	validation-rmse:6.62697
# [145]	validation-rmse:6.62675
# [146]	validation-rmse:6.62663
# [147]	validation-rmse:6.62676
# [148]	validation-rmse:6.62660
# [149]	validation-rmse:6.62669
# [150]	validation-rmse:6.62657
# [151]	validation-rmse:6.62633
# [152]	validation-rmse:6.62627
# [153]	validation-rmse:6.62636
# [154]	validation-rmse:6.62619
# [155]	validation-rmse:6.62629
# [156]	validation-rmse:6.62616
# [157]	validation-rmse:6.62612
# [158]	validation-rmse:6.62606
# [159]	validation-rmse:6.62606
# [160]	validation-rmse:6.62602
# [161]	validation-rmse:6.62569
# [162]	validation-rmse:6.62574
# [163]	validation-rmse:6.62583
# [164]	validation-rmse:6.62578
# [165]	validation-rmse:6.62549
# [166]	validation-rmse:6.62547
# [167]	validation-rmse:6.62566
# [168]	validation-rmse:6.62562
# [169]	validation-rmse:6.62569
# [170]	validation-rmse:6.62565
# [171]	validation-rmse:6.62573
# [172]	validation-rmse:6.62578
# [173]	validation-rmse:6.62569
# [174]	validation-rmse:6.62564
# [175]	validation-rmse:6.62579
# [176]	validation-rmse:6.62558
# [177]	validation-rmse:6.62558
# [178]	validation-rmse:6.62557
# [179]	validation-rmse:6.62559
# [180]	validation-rmse:6.62540
# [181]	validation-rmse:6.62548
# [182]	validation-rmse:6.62543
# [183]	validation-rmse:6.62548
# [184]	validation-rmse:6.62553
# [185]	validation-rmse:6.62541
# [186]	validation-rmse:6.62516
# [187]	validation-rmse:6.62517
# [188]	validation-rmse:6.62507
# [189]	validation-rmse:6.62513
# [190]	validation-rmse:6.62466
# [191]	validation-rmse:6.62506
# [192]	validation-rmse:6.62512
# [193]	validation-rmse:6.62514
# [194]	validation-rmse:6.62505
# [195]	validation-rmse:6.62518
# [196]	validation-rmse:6.62565
# [197]	validation-rmse:6.62542
# [198]	validation-rmse:6.62542
# [199]	validation-rmse:6.62544
# [200]	validation-rmse:6.62537
# [201]	validation-rmse:6.62521
# [202]	validation-rmse:6.62518
# [203]	validation-rmse:6.62491
# [204]	validation-rmse:6.62499
# [205]	validation-rmse:6.62483
# [206]	validation-rmse:6.62467
# [207]	validation-rmse:6.62464
# [208]	validation-rmse:6.62472
# [209]	validation-rmse:6.62456
# [210]	validation-rmse:6.62491
# [211]	validation-rmse:6.62583
# [212]	validation-rmse:6.62573
# [213]	validation-rmse:6.62559
# [214]	validation-rmse:6.62582
# [215]	validation-rmse:6.62555
# [216]	validation-rmse:6.62620
# [217]	validation-rmse:6.62636
# [218]	validation-rmse:6.62649
# [219]	validation-rmse:6.62651
# [220]	validation-rmse:6.62626
# [221]	validation-rmse:6.62626
# [222]	validation-rmse:6.62633
# [223]	validation-rmse:6.62640
# [224]	validation-rmse:6.62629
# [225]	validation-rmse:6.62599
# [226]	validation-rmse:6.62607
# [227]	validation-rmse:6.62607
# [228]	validation-rmse:6.62593
# [229]	validation-rmse:6.62597
# [230]	validation-rmse:6.62621
# [231]	validation-rmse:6.62611
# [232]	validation-rmse:6.62604
# [233]	validation-rmse:6.62632
# [234]	validation-rmse:6.62662
# [235]	validation-rmse:6.62688
# [236]	validation-rmse:6.62674
# [237]	validation-rmse:6.62674
# [238]	validation-rmse:6.62678
# [239]	validation-rmse:6.62693
# [240]	validation-rmse:6.62688
# [241]	validation-rmse:6.62681
# [242]	validation-rmse:6.62688
# [243]	validation-rmse:6.62664
# [244]	validation-rmse:6.62677
# [245]	validation-rmse:6.62670
# [246]	validation-rmse:6.62678
# [247]	validation-rmse:6.62676
# [248]	validation-rmse:6.62677
# [249]	validation-rmse:6.62656
# [250]	validation-rmse:6.62645
# [251]	validation-rmse:6.62659
# [252]	validation-rmse:6.62655
# [253]	validation-rmse:6.62656
# [254]	validation-rmse:6.62653
# [255]	validation-rmse:6.62654
# [256]	validation-rmse:6.62658
# [257]	validation-rmse:6.62702
# [258]	validation-rmse:6.62697
# [11:59:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.65982
# [1]	validation-rmse:16.52606
# [2]	validation-rmse:14.73696
# [3]	validation-rmse:13.24454
# [4]	validation-rmse:12.00743
# [5]	validation-rmse:10.98777
# [6]	validation-rmse:10.15242
# [7]	validation-rmse:9.47383
# [8]	validation-rmse:8.92493
# [9]	validation-rmse:8.48387
# [10]	validation-rmse:8.12954
# [11]	validation-rmse:7.84490
# [12]	validation-rmse:7.61852
# [13]	validation-rmse:7.43676
# [14]	validation-rmse:7.29143
# [15]	validation-rmse:7.17428
# [16]	validation-rmse:7.08125
# [17]	validation-rmse:7.00474
# [18]	validation-rmse:6.94284
# [19]	validation-rmse:6.89218
# [20]	validation-rmse:6.85100
# [21]	validation-rmse:6.81755
# [22]	validation-rmse:6.78944
# [23]	validation-rmse:6.76634
# [24]	validation-rmse:6.74584
# [25]	validation-rmse:6.72828
# [26]	validation-rmse:6.71365
# [27]	validation-rmse:6.70085
# [28]	validation-rmse:6.69004
# [29]	validation-rmse:6.68071
# [30]	validation-rmse:6.67231
# [31]	validation-rmse:6.66519
# [32]	validation-rmse:6.65941
# [33]	validation-rmse:6.65430
# [34]	validation-rmse:6.64976
# [35]	validation-rmse:6.64560
# [36]	validation-rmse:6.64226
# [37]	validation-rmse:6.64000
# [38]	validation-rmse:6.63683
# [39]	validation-rmse:6.63475
# [40]	validation-rmse:6.63280
# [41]	validation-rmse:6.63103
# [42]	validation-rmse:6.62913
# [43]	validation-rmse:6.62809
# [44]	validation-rmse:6.62704
# [45]	validation-rmse:6.62593
# [46]	validation-rmse:6.62464
# [47]	validation-rmse:6.62373
# [48]	validation-rmse:6.62209
# [49]	validation-rmse:6.62116
# [50]	validation-rmse:6.62034
# [51]	validation-rmse:6.61954
# [52]	validation-rmse:6.61874
# [53]	validation-rmse:6.61801
# [54]	validation-rmse:6.61696
# [55]	validation-rmse:6.61662
# [56]	validation-rmse:6.61629
# [57]	validation-rmse:6.61553
# [58]	validation-rmse:6.61479
# [59]	validation-rmse:6.61438
# [60]	validation-rmse:6.61382
# [61]	validation-rmse:6.61320
# [62]	validation-rmse:6.61279
# [63]	validation-rmse:6.61227
# [64]	validation-rmse:6.61181
# [65]	validation-rmse:6.61118
# [66]	validation-rmse:6.61059
# [67]	validation-rmse:6.61009
# [68]	validation-rmse:6.60980
# [69]	validation-rmse:6.60932
# [70]	validation-rmse:6.60896
# [71]	validation-rmse:6.60869
# [72]	validation-rmse:6.60861
# [73]	validation-rmse:6.60819
# [74]	validation-rmse:6.60771
# [75]	validation-rmse:6.60718
# [76]	validation-rmse:6.60676
# [77]	validation-rmse:6.60632
# [78]	validation-rmse:6.60581
# [79]	validation-rmse:6.60541
# [80]	validation-rmse:6.60497
# [81]	validation-rmse:6.60455
# [82]	validation-rmse:6.60426
# [83]	validation-rmse:6.60388
# [84]	validation-rmse:6.60320
# [85]	validation-rmse:6.60298
# [86]	validation-rmse:6.60265
# [87]	validation-rmse:6.60259
# [88]	validation-rmse:6.60216
# [89]	validation-rmse:6.60184
# [90]	validation-rmse:6.60150
# [91]	validation-rmse:6.60146
# [92]	validation-rmse:6.60133
# [93]	validation-rmse:6.60098
# [94]	validation-rmse:6.60058
# [95]	validation-rmse:6.60032
# [96]	validation-rmse:6.59993
# [97]	validation-rmse:6.59958
# [98]	validation-rmse:6.59935
# [99]	validation-rmse:6.59889
# [100]	validation-rmse:6.59875
# [101]	validation-rmse:6.59774
# [102]	validation-rmse:6.59699
# [103]	validation-rmse:6.59675
# [104]	validation-rmse:6.59660
# [105]	validation-rmse:6.59631
# [106]	validation-rmse:6.59602
# [107]	validation-rmse:6.59592
# [108]	validation-rmse:6.59585
# [109]	validation-rmse:6.59561
# [110]	validation-rmse:6.59502
# [111]	validation-rmse:6.59460
# [112]	validation-rmse:6.59446
# [113]	validation-rmse:6.59423
# [114]	validation-rmse:6.59409
# [115]	validation-rmse:6.59407
# [116]	validation-rmse:6.59405
# [117]	validation-rmse:6.59366
# [118]	validation-rmse:6.59341
# [119]	validation-rmse:6.59304
# [120]	validation-rmse:6.59289
# [121]	validation-rmse:6.59270
# [122]	validation-rmse:6.59247
# [123]	validation-rmse:6.59229
# [124]	validation-rmse:6.59205
# [125]	validation-rmse:6.59187
# [126]	validation-rmse:6.59161
# [127]	validation-rmse:6.59168
# [128]	validation-rmse:6.59150
# [129]	validation-rmse:6.59132
# [130]	validation-rmse:6.59119
# [131]	validation-rmse:6.59095
# [132]	validation-rmse:6.59081
# [133]	validation-rmse:6.59062
# [134]	validation-rmse:6.59046
# [135]	validation-rmse:6.59033
# [136]	validation-rmse:6.59008
# [137]	validation-rmse:6.58998
# [138]	validation-rmse:6.58987
# [139]	validation-rmse:6.58948
# [140]	validation-rmse:6.58934
# [141]	validation-rmse:6.58812
# [142]	validation-rmse:6.58788
# [143]	validation-rmse:6.58721
# [144]	validation-rmse:6.58616
# [145]	validation-rmse:6.58555
# [146]	validation-rmse:6.58554
# [147]	validation-rmse:6.58499
# [148]	validation-rmse:6.58464
# [149]	validation-rmse:6.58462
# [150]	validation-rmse:6.58431
# [151]	validation-rmse:6.58395
# [152]	validation-rmse:6.58366
# [153]	validation-rmse:6.58372
# [154]	validation-rmse:6.58349
# [155]	validation-rmse:6.58302
# [156]	validation-rmse:6.58271
# [157]	validation-rmse:6.58236
# [158]	validation-rmse:6.58155
# [159]	validation-rmse:6.58136
# [160]	validation-rmse:6.58124
# [161]	validation-rmse:6.58100
# [162]	validation-rmse:6.58064
# [163]	validation-rmse:6.58044
# [164]	validation-rmse:6.58032
# [165]	validation-rmse:6.57993
# [166]	validation-rmse:6.57973
# [167]	validation-rmse:6.57963
# [168]	validation-rmse:6.57935
# [169]	validation-rmse:6.57911
# [170]	validation-rmse:6.57885
# [171]	validation-rmse:6.57851
# [172]	validation-rmse:6.57824
# [173]	validation-rmse:6.57801
# [174]	validation-rmse:6.57786
# [175]	validation-rmse:6.57766
# [176]	validation-rmse:6.57737
# [177]	validation-rmse:6.57729
# [178]	validation-rmse:6.57712
# [179]	validation-rmse:6.57686
# [180]	validation-rmse:6.57666
# [181]	validation-rmse:6.57666
# [182]	validation-rmse:6.57635
# [183]	validation-rmse:6.57589
# [184]	validation-rmse:6.57581
# [185]	validation-rmse:6.57564
# [186]	validation-rmse:6.57559
# [187]	validation-rmse:6.57534
# [188]	validation-rmse:6.57531
# [189]	validation-rmse:6.57519
# [190]	validation-rmse:6.57504
# [191]	validation-rmse:6.57509
# [192]	validation-rmse:6.57503
# [193]	validation-rmse:6.57501
# [194]	validation-rmse:6.57483
# [195]	validation-rmse:6.57479
# [196]	validation-rmse:6.57474
# [197]	validation-rmse:6.57459
# [198]	validation-rmse:6.57452
# [199]	validation-rmse:6.57434
# [200]	validation-rmse:6.57430
# [201]	validation-rmse:6.57425
# [202]	validation-rmse:6.57418
# [203]	validation-rmse:6.57398
# [204]	validation-rmse:6.57397
# [205]	validation-rmse:6.57367
# [206]	validation-rmse:6.57357
# [207]	validation-rmse:6.57343
# [208]	validation-rmse:6.57327
# [209]	validation-rmse:6.57312
# [210]	validation-rmse:6.57297
# [211]	validation-rmse:6.57281
# [212]	validation-rmse:6.57264
# [213]	validation-rmse:6.57250
# [214]	validation-rmse:6.57245
# [215]	validation-rmse:6.57231
# [216]	validation-rmse:6.57213
# [217]	validation-rmse:6.57201
# [218]	validation-rmse:6.57193
# [219]	validation-rmse:6.57180
# [220]	validation-rmse:6.57166
# [221]	validation-rmse:6.57159
# [222]	validation-rmse:6.57140
# [223]	validation-rmse:6.57130
# [224]	validation-rmse:6.57117
# [225]	validation-rmse:6.57104
# [226]	validation-rmse:6.57081
# [227]	validation-rmse:6.57082
# [228]	validation-rmse:6.57062
# [229]	validation-rmse:6.57052
# [230]	validation-rmse:6.57046
# [231]	validation-rmse:6.57036
# [232]	validation-rmse:6.57027
# [233]	validation-rmse:6.57007
# [234]	validation-rmse:6.56997
# [235]	validation-rmse:6.56985
# [236]	validation-rmse:6.56970
# [237]	validation-rmse:6.56965
# [238]	validation-rmse:6.56964
# [239]	validation-rmse:6.56948
# [240]	validation-rmse:6.56938
# [241]	validation-rmse:6.56939
# [242]	validation-rmse:6.56936
# [243]	validation-rmse:6.56931
# [244]	validation-rmse:6.56926
# [245]	validation-rmse:6.56926
# [246]	validation-rmse:6.56925
# [247]	validation-rmse:6.56923
# [248]	validation-rmse:6.56922
# [249]	validation-rmse:6.56925
# [250]	validation-rmse:6.56916
# [251]	validation-rmse:6.56900
# [252]	validation-rmse:6.56893
# [253]	validation-rmse:6.56882
# [254]	validation-rmse:6.56870
# [255]	validation-rmse:6.56856
# [256]	validation-rmse:6.56850
# [257]	validation-rmse:6.56845
# [258]	validation-rmse:6.56839
# [259]	validation-rmse:6.56837
# [260]	validation-rmse:6.56831
# [261]	validation-rmse:6.56819
# [262]	validation-rmse:6.56807
# [263]	validation-rmse:6.56811
# [264]	validation-rmse:6.56806
# [265]	validation-rmse:6.56796
# [266]	validation-rmse:6.56793
# [267]	validation-rmse:6.56786
# [268]	validation-rmse:6.56780
# [269]	validation-rmse:6.56762
# [270]	validation-rmse:6.56750
# [271]	validation-rmse:6.56750
# [272]	validation-rmse:6.56741
# [273]	validation-rmse:6.56729
# [274]	validation-rmse:6.56727
# [275]	validation-rmse:6.56700
# [276]	validation-rmse:6.56694
# [277]	validation-rmse:6.56696
# [278]	validation-rmse:6.56669
# [279]	validation-rmse:6.56662
# [280]	validation-rmse:6.56667
# [281]	validation-rmse:6.56640
# [282]	validation-rmse:6.56632
# [283]	validation-rmse:6.56614
# [284]	validation-rmse:6.56610
# [285]	validation-rmse:6.56606
# [286]	validation-rmse:6.56614
# [287]	validation-rmse:6.56595
# [288]	validation-rmse:6.56583
# [289]	validation-rmse:6.56584
# [290]	validation-rmse:6.56580
# [291]	validation-rmse:6.56570
# [292]	validation-rmse:6.56560
# [293]	validation-rmse:6.56562
# [294]	validation-rmse:6.56547
# [295]	validation-rmse:6.56527
# [296]	validation-rmse:6.56519
# [297]	validation-rmse:6.56509
# [298]	validation-rmse:6.56507
# [299]	validation-rmse:6.56502
# [300]	validation-rmse:6.56495
# [301]	validation-rmse:6.56499
# [302]	validation-rmse:6.56487
# [303]	validation-rmse:6.56480
# [304]	validation-rmse:6.56497
# [305]	validation-rmse:6.56498
# [306]	validation-rmse:6.56486
# [307]	validation-rmse:6.56482
# [308]	validation-rmse:6.56475
# [309]	validation-rmse:6.56468
# [310]	validation-rmse:6.56474
# [311]	validation-rmse:6.56456
# [312]	validation-rmse:6.56443
# [313]	validation-rmse:6.56435
# [314]	validation-rmse:6.56432
# [315]	validation-rmse:6.56406
# [316]	validation-rmse:6.56410
# [317]	validation-rmse:6.56405
# [318]	validation-rmse:6.56397
# [319]	validation-rmse:6.56395
# [320]	validation-rmse:6.56395
# [321]	validation-rmse:6.56392
# [322]	validation-rmse:6.56387
# [323]	validation-rmse:6.56387
# [324]	validation-rmse:6.56379
# [325]	validation-rmse:6.56377
# [326]	validation-rmse:6.56368
# [327]	validation-rmse:6.56357
# [328]	validation-rmse:6.56356
# [329]	validation-rmse:6.56350
# [330]	validation-rmse:6.56342
# [331]	validation-rmse:6.56340
# [332]	validation-rmse:6.56331
# [333]	validation-rmse:6.56323
# [334]	validation-rmse:6.56309
# [335]	validation-rmse:6.56295
# [336]	validation-rmse:6.56293
# [337]	validation-rmse:6.56290
# [338]	validation-rmse:6.56275
# [339]	validation-rmse:6.56272
# [340]	validation-rmse:6.56281
# [341]	validation-rmse:6.56264
# [342]	validation-rmse:6.56259
# [343]	validation-rmse:6.56252
# [344]	validation-rmse:6.56260
# [345]	validation-rmse:6.56251
# [346]	validation-rmse:6.56246
# [347]	validation-rmse:6.56238
# [348]	validation-rmse:6.56229
# [349]	validation-rmse:6.56225
# [350]	validation-rmse:6.56205
# [351]	validation-rmse:6.56219
# [352]	validation-rmse:6.56210
# [353]	validation-rmse:6.56205
# [354]	validation-rmse:6.56198
# [355]	validation-rmse:6.56183
# [356]	validation-rmse:6.56181
# [357]	validation-rmse:6.56177
# [358]	validation-rmse:6.56181
# [359]	validation-rmse:6.56169
# [360]	validation-rmse:6.56158
# [361]	validation-rmse:6.56160
# [362]	validation-rmse:6.56154
# [363]	validation-rmse:6.56150
# [364]	validation-rmse:6.56139
# [365]	validation-rmse:6.56139
# [366]	validation-rmse:6.56137
# [367]	validation-rmse:6.56142
# [368]	validation-rmse:6.56140
# [369]	validation-rmse:6.56170
# [370]	validation-rmse:6.56192
# [371]	validation-rmse:6.56180
# [372]	validation-rmse:6.56178
# [373]	validation-rmse:6.56173
# [374]	validation-rmse:6.56172
# [375]	validation-rmse:6.56174
# [376]	validation-rmse:6.56181
# [377]	validation-rmse:6.56175
# [378]	validation-rmse:6.56172
# [379]	validation-rmse:6.56179
# [380]	validation-rmse:6.56176
# [381]	validation-rmse:6.56170
# [382]	validation-rmse:6.56183
# [383]	validation-rmse:6.56161
# [384]	validation-rmse:6.56162
# [385]	validation-rmse:6.56165
# [386]	validation-rmse:6.56162
# [387]	validation-rmse:6.56162
# [388]	validation-rmse:6.56161
# [389]	validation-rmse:6.56165
# [390]	validation-rmse:6.56167
# [391]	validation-rmse:6.56175
# [392]	validation-rmse:6.56174
# [393]	validation-rmse:6.56164
# [394]	validation-rmse:6.56155
# [395]	validation-rmse:6.56150
# [396]	validation-rmse:6.56139
# [397]	validation-rmse:6.56142
# [398]	validation-rmse:6.56136
# [399]	validation-rmse:6.56137
# [400]	validation-rmse:6.56131
# [401]	validation-rmse:6.56125
# [402]	validation-rmse:6.56127
# [403]	validation-rmse:6.56113
# [404]	validation-rmse:6.56102
# [405]	validation-rmse:6.56099
# [406]	validation-rmse:6.56102
# [407]	validation-rmse:6.56097
# [408]	validation-rmse:6.56088
# [409]	validation-rmse:6.56080
# [410]	validation-rmse:6.56079
# ...
# [584]	validation-rmse:6.44346
# [585]	validation-rmse:6.44334
# [586]	validation-rmse:6.44329
# [587]	validation-rmse:6.44327
# [588]	validation-rmse:6.44317
# [589]	validation-rmse:6.44311
# [590]	validation-rmse:6.44299
# [591]	validation-rmse:6.44301
# [592]	validation-rmse:6.44292
# [593]	validation-rmse:6.44309
# [594]	validation-rmse:6.44299
# [595]	validation-rmse:6.44295
# [596]	validation-rmse:6.44297
# [597]	validation-rmse:6.44299
# [598]	validation-rmse:6.44291
# [599]	validation-rmse:6.44295
# [600]	validation-rmse:6.44283
# [601]	validation-rmse:6.44290
# [602]	validation-rmse:6.44293
# [603]	validation-rmse:6.44295
# [604]	validation-rmse:6.44298
# [605]	validation-rmse:6.44297
# [606]	validation-rmse:6.44285
# [607]	validation-rmse:6.44284
# [608]	validation-rmse:6.44276
# [609]	validation-rmse:6.44268
# [610]	validation-rmse:6.44261
# [611]	validation-rmse:6.44256
# [612]	validation-rmse:6.44255
# [613]	validation-rmse:6.44256
# [614]	validation-rmse:6.44247
# [615]	validation-rmse:6.44242
# [616]	validation-rmse:6.44246
# [617]	validation-rmse:6.44232
# [618]	validation-rmse:6.44224
# [619]	validation-rmse:6.44223
# [620]	validation-rmse:6.44227
# [621]	validation-rmse:6.44223
# [622]	validation-rmse:6.44218
# [623]	validation-rmse:6.44213
# [624]	validation-rmse:6.44209
# [625]	validation-rmse:6.44208
# [626]	validation-rmse:6.44211
# [627]	validation-rmse:6.44200
# [628]	validation-rmse:6.44197
# [629]	validation-rmse:6.44193
# [630]	validation-rmse:6.44194
# [631]	validation-rmse:6.44193
# [632]	validation-rmse:6.44180
# [633]	validation-rmse:6.44174
# [634]	validation-rmse:6.44174
# [635]	validation-rmse:6.44156
# [636]	validation-rmse:6.44159
# [637]	validation-rmse:6.44159
# [638]	validation-rmse:6.44156
# [639]	validation-rmse:6.44149
# [640]	validation-rmse:6.44146
# [641]	validation-rmse:6.44142
# [642]	validation-rmse:6.44141
# [643]	validation-rmse:6.44143
# [644]	validation-rmse:6.44138
# [645]	validation-rmse:6.44133
# [646]	validation-rmse:6.44131
# [647]	validation-rmse:6.44131
# [648]	validation-rmse:6.44130
# [649]	validation-rmse:6.44133
# [650]	validation-rmse:6.44135
# [651]	validation-rmse:6.44127
# [652]	validation-rmse:6.44127
# [653]	validation-rmse:6.44120
# [654]	validation-rmse:6.44114
# [655]	validation-rmse:6.44109
# [656]	validation-rmse:6.44092
# [657]	validation-rmse:6.44094
# [658]	validation-rmse:6.44085
# [659]	validation-rmse:6.44092
# [660]	validation-rmse:6.44135
# [661]	validation-rmse:6.44139
# [662]	validation-rmse:6.44140
# [663]	validation-rmse:6.44136
# [664]	validation-rmse:6.44130
# [665]	validation-rmse:6.44126
# [666]	validation-rmse:6.44124
# [667]	validation-rmse:6.44122
# [668]	validation-rmse:6.44113
# [669]	validation-rmse:6.44095
# [670]	validation-rmse:6.44092
# [671]	validation-rmse:6.44091
# [672]	validation-rmse:6.44080
# [673]	validation-rmse:6.44067
# [674]	validation-rmse:6.44066
# [675]	validation-rmse:6.44083
# [676]	validation-rmse:6.44081
# [677]	validation-rmse:6.44085
# [678]	validation-rmse:6.44084
# [679]	validation-rmse:6.44078
# [680]	validation-rmse:6.44060
# [681]	validation-rmse:6.44062
# [682]	validation-rmse:6.44064
# [683]	validation-rmse:6.44060
# [684]	validation-rmse:6.44062
# [685]	validation-rmse:6.44059
# [686]	validation-rmse:6.44055
# [687]	validation-rmse:6.44043
# [688]	validation-rmse:6.44044
# [689]	validation-rmse:6.44045
# [690]	validation-rmse:6.44035
# [691]	validation-rmse:6.44038
# [692]	validation-rmse:6.44035
# [693]	validation-rmse:6.44037
# [694]	validation-rmse:6.44028
# [695]	validation-rmse:6.44033
# [696]	validation-rmse:6.44032
#  14%|█▍        | 7/50 [09:17<57:05, 79.65s/trial, best loss: 6.358963287013722]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 11
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       8     'seed': 42,
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials()
#      17 )
#
# File ~/mambaforge/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/mambaforge/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/mambaforge/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/mambaforge/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/mambaforge/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/mambaforge/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/mambaforge/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[24], line 6, in objective(params)
#       4 mlflow.set_tag('model', 'xgboost')
#       5 mlflow.log_params(params)
# ----> 6 booster = xgb.train(
#       7     params = params,
#       8     dtrain=train,
#       9     num_boost_round=1000,
#      10     evals=[(valid,'validation')],
#      11     early_stopping_rounds=50
#      12 )
#      13 y_pred = booster.predict(valid)
#      14 rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File ~/mambaforge/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/mambaforge/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~/mambaforge/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
